# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/solar_weather_dust_dataset.csv")

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.head()
# Out:
#                   time  ambient_temperature  module_temperature  irradiation  \
# 0  2024-01-01 06:00:00            29.363503           38.336289   502.427659
# 1  2024-01-01 06:10:00            43.767858           50.733285   574.962780
# 2  2024-01-01 06:20:00            38.299849           47.720833   877.763782
# 3  2024-01-01 06:30:00            34.966462           43.893786   565.225335
# 4  2024-01-01 06:40:00            23.900466           38.466137  1022.526861
#
#    dust_accumulation_g_m2  dust_loss_percentage    dc_power    ac_power  \
# 0                0.000746              0.000187  150.700182  143.165173
# 1                0.002019              0.000505  172.401780  163.781691
# 2                0.003459              0.000865  263.101422  249.946351
# 3                0.004708              0.001177  169.368007  160.899607
# 4                0.005737              0.001434  306.318059  291.002156
#
#    daily_yield  total_yield
# 0     0.143165     0.143165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   time                    10000 non-null  object
#  1   ambient_temperature     10000 non-null  float64
#  2   module_temperature      10000 non-null  float64
#  3   irradiation             10000 non-null  float64
#  4   dust_accumulation_g_m2  10000 non-null  float64
#  5   dust_loss_percentage    10000 non-null  float64
#  6   dc_power                10000 non-null  float64
#  7   ac_power                10000 non-null  float64
#  8   daily_yield             10000 non-null  float64
#  9   total_yield             10000 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#        ambient_temperature  module_temperature   irradiation  \
# count         10000.000000        10000.000000  10000.000000
# mean             32.353989           44.805367    802.471079
# std               7.190753            8.400507    199.954894
# min              20.000291           25.184555     15.519950
# 25%              26.158222           38.447379    668.318913
# 50%              32.313215           44.831678    803.361358
# 75%              38.500159           51.169204    936.475278
# max              44.992942           64.840884   1695.816850
#
#        dust_accumulation_g_m2  dust_loss_percentage      dc_power  \
# count            10000.000000          10000.000000  10000.000000
# mean                 0.487502              0.121875    211.405180
# std                  0.063350              0.015838     52.862490
# min                  0.000746              0.000187      4.073987
# 25%                  0.500000              0.125000    175.910139
# ...

# %%
# Drop columns 'Col1' and 'Col2'
df.drop(['time', 'dc_power', 'ac_power', 'daily_yield'], axis=1, inplace=True)

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df.hist(bins=50, figsize=(12, 8))
plt.show()

# %%
features = ["ambient_temperature",
            "module_temperature",
            "irradiation",
            "dust_accumulation_g_m2",
            "dust_loss_percentage",
            "total_yield"]
pd.plotting.scatter_matrix(df[features], figsize=(12, 8))
plt.show()

# %%
corr_ = df.corr()
corr_['total_yield'].sort_values(ascending=True)
# Out:
# ambient_temperature      -0.011063
# module_temperature       -0.010217
# irradiation               0.008562
# dust_accumulation_g_m2    0.331061
# dust_loss_percentage      0.331061
# total_yield               1.000000
# Name: total_yield, dtype: float64
